# %% [markdown]
# <a href="https://colab.research.google.com/github/ighoshsubho/Bloom-api/blob/main/Fastest_way_to_create_an_ML_API_with_Chitra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -U "chitra[serve]" -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 32.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 KB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.0/264.0 KB 20.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.7/140.7 KB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 KB 7.3 MB/s eta 0:00:00
# ...

# %%
! pip install tornado==4.5.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.2/484.2 KB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tornado: filename=tornado-4.5.3-cp38-cp38-linux_x86_64.whl size=433394 sha256=9973dc6017bf2d6fd97df106de0b5616f6d886391b75e2d06773b6fc3a86feb6
#   Stored in directory: /root/.cache/pip/wheels/20/fe/26/0c03adccd0cec2744261ec6b8380fbe5e726d1ea4cf3a9370e
# Successfully built tornado
# ...
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.2
#     Uninstalling tornado-6.2:
#       Successfully uninstalled tornado-6.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# notebook 6.3.0 requires tornado>=6.1, but you have tornado 4.5.3 which is incompatible.
# ...

# %%
! pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 41.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 110.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 22.7 MB/s eta 0:00:00

# %%
from transformers import pipeline

# %%
from chitra.serve import create_api

# %%
classifier = pipeline("text-generation",model="Gustavosta/MagicPrompt-Stable-Diffusion")

# %%
# !pip install nest-asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
create_api(classifier, run=True, api_type="text-classification")
# Out:
# INFO:     Started server process [235]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [235]

# %%
# %%writefile app.py
from transformers import pipeline
from chitra.serve import create_api
classifier = pipeline("text-generation",model="Gustavosta/MagicPrompt-Stable-Diffusion")
cr_api = create_api(classifier, run=False, api_type="text-classification")
cr_api.run()
# Out:
# Overwriting app.py

# %%
import subprocess
subprocess.Popen(["python", "app.py"])

# %%
! npx localtunnel --port 8000
# Out:
# npx: installed 22 in 2.153s
# your url is: https://grumpy-corners-hug-34-121-18-113.loca.lt
# ^C
